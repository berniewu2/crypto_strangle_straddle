# %%
import pandas as pd
import ccxt
import time
import datetime

# %%
import json
import requests
import pandas as pd
from tqdm import tqdm
import sqlite3
import datetime


# functions
def get_option_name_and_settlement(coin):
    """ 
    :param coin: crypto-currency coin name ('BTC', 'ETH')
    :return: 2 lists:
                        1.  list of traded options for the selected coin;
                        2.  list of settlement period for the selected coin.
    """

    # requests public API
    r = requests.get("https://test.deribit.com/api/v2/public/get_instruments?currency=" + coin + "&kind=option")
    result = json.loads(r.text)

    # get option name
    name = pd.json_normalize(result['result'])['instrument_name']
    name = list(name)

    # get option settlement period
    settlement_period = pd.json_normalize(result['result'])['settlement_period']
    settlement_period = list(settlement_period)

    return name, settlement_period


def get_option_data(coin):
    """
    :param coin: crypto-currency coin name ('BTC', 'ETH')
    :return: pandas data frame with all option data for a given coin
    """

    # get option name and settlement
    coin_name = get_option_name_and_settlement(coin)[0]
    settlement_period = get_option_name_and_settlement(coin)[1]

    # initialize data frame
    coin_df = []

    # initialize progress bar
    pbar = tqdm(total=len(coin_name))

    # loop to download data for each Option Name
    for i in range(len(coin_name)):
        # download option data -- requests and convert json to pandas
        r = requests.get('https://test.deribit.com/api/v2/public/get_order_book?instrument_name=' + coin_name[i])
        result = json.loads(r.text)
        df = pd.json_normalize(result['result'])

        # add settlement period
        df['settlement_period'] = settlement_period[i]

        # append data to data frame
        coin_df.append(df)

        # update progress bar
        pbar.update(1)

    # finalize data frame
    coin_df = pd.concat(coin_df)

    # remove useless columns from coin_df
    columns = ['state', 'estimated_delivery_price']
    coin_df.drop(columns, inplace=True, axis=1)

    # close the progress bar
    pbar.close()

    return coin_df


# print data and time for log
print('Date and time: ' +  datetime.datetime.now().strftime("%d/%m/%Y %H:%M:%S") + ' , format: dd/mm/yyyy hh:mm:ss')

# download data -- BTC and ETH Options
btc_data = get_option_data('BTC')
# Out:
# Date and time: 18/10/2023 18:28:23 , format: dd/mm/yyyy hh:mm:ss
#   2%|▏         | 9/378 [00:04<03:05,  1.99it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\desktop\Documents\GitHub\crypto_strangle_straddle\main.ipynb Cell 2 line 8
#      <a href='vscode-notebook-cell:/c%3A/Users/desktop/Documents/GitHub/crypto_strangle_straddle/main.ipynb#W1sZmlsZQ%3D%3D?line=78'>79</a> print('Date and time: ' +  datetime.datetime.now().strftime("%d/%m/%Y %H:%M:%S") + ' , format: dd/mm/yyyy hh:mm:ss')
#      <a href='vscode-notebook-cell:/c%3A/Users/desktop/Documents/GitHub/crypto_strangle_straddle/main.ipynb#W1sZmlsZQ%3D%3D?line=80'>81</a> # download data -- BTC and ETH Options
# ---> <a href='vscode-notebook-cell:/c%3A/Users/desktop/Documents/GitHub/crypto_strangle_straddle/main.ipynb#W1sZmlsZQ%3D%3D?line=81'>82</a> btc_data = get_option_data('BTC')
#
# c:\Users\desktop\Documents\GitHub\crypto_strangle_straddle\main.ipynb Cell 2 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/desktop/Documents/GitHub/crypto_strangle_straddle/main.ipynb#W1sZmlsZQ%3D%3D?line=48'>49</a> # loop to download data for each Option Name
#      <a href='vscode-notebook-cell:/c%3A/Users/desktop/Documents/GitHub/crypto_strangle_straddle/main.ipynb#W1sZmlsZQ%3D%3D?line=49'>50</a> for i in range(len(coin_name)):
#      <a href='vscode-notebook-cell:/c%3A/Users/desktop/Documents/GitHub/crypto_strangle_straddle/main.ipynb#W1sZmlsZQ%3D%3D?line=50'>51</a>     # download option data -- requests and convert json to pandas
# ---> <a href='vscode-notebook-cell:/c%3A/Users/desktop/Documents/GitHub/crypto_strangle_straddle/main.ipynb#W1sZmlsZQ%3D%3D?line=51'>52</a>     r = requests.get('https://test.deribit.com/api/v2/public/get_order_book?instrument_name=' + coin_name[i])
#      <a href='vscode-notebook-cell:/c%3A/Users/desktop/Documents/GitHub/crypto_strangle_straddle/main.ipynb#W1sZmlsZQ%3D%3D?line=52'>53</a>     result = json.loads(r.text)
#      <a href='vscode-notebook-cell:/c%3A/Users/desktop/Documents/GitHub/crypto_strangle_straddle/main.ipynb#W1sZmlsZQ%3D%3D?line=53'>54</a>     df = pd.json_normalize(result['result'])
#
# File c:\Users\desktop\Documents\GitHub\crypto_strangle_straddle\.venv\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\desktop\Documents\GitHub\crypto_strangle_straddle\.venv\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\desktop\Documents\GitHub\crypto_strangle_straddle\.venv\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\desktop\Documents\GitHub\crypto_strangle_straddle\.venv\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\desktop\Documents\GitHub\crypto_strangle_straddle\.venv\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\desktop\Documents\GitHub\crypto_strangle_straddle\.venv\lib\site-packages\urllib3\connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File c:\Users\desktop\Documents\GitHub\crypto_strangle_straddle\.venv\lib\site-packages\urllib3\connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
#     466     # Trigger any extra validation we need to do.
#     467     try:
# --> 468         self._validate_conn(conn)
#     469     except (SocketTimeout, BaseSSLError) as e:
#     470         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\desktop\Documents\GitHub\crypto_strangle_straddle\.venv\lib\site-packages\urllib3\connectionpool.py:1097, in HTTPSConnectionPool._validate_conn(self, conn)
#    1095 # Force connect early to allow us to validate the connection.
#    1096 if conn.is_closed:
# -> 1097     conn.connect()
#    1099 if not conn.is_verified:
#    1100     warnings.warn(
#    1101         (
#    1102             f"Unverified HTTPS request is being made to host '{conn.host}'. "
#    (...)
#    1107         InsecureRequestWarning,
#    1108     )
#
# File c:\Users\desktop\Documents\GitHub\crypto_strangle_straddle\.venv\lib\site-packages\urllib3\connection.py:611, in HTTPSConnection.connect(self)
#     609 def connect(self) -> None:
#     610     sock: socket.socket | ssl.SSLSocket
# --> 611     self.sock = sock = self._new_conn()
#     612     server_hostname: str = self.host
#     613     tls_in_tls = False
#
# File c:\Users\desktop\Documents\GitHub\crypto_strangle_straddle\.venv\lib\site-packages\urllib3\connection.py:203, in HTTPConnection._new_conn(self)
#     198 """Establish a socket connection and set nodelay settings on it.
#     199
#     200 :return: New socket connection.
#     201 """
#     202 try:
# --> 203     sock = connection.create_connection(
#     204         (self._dns_host, self.port),
#     205         self.timeout,
#     206         source_address=self.source_address,
#     207         socket_options=self.socket_options,
#     208     )
#     209 except socket.gaierror as e:
#     210     raise NameResolutionError(self.host, self, e) from e
#
# File c:\Users\desktop\Documents\GitHub\crypto_strangle_straddle\.venv\lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:

# %%
r = requests.get("https://test.deribit.com/api/v2/public/get_instruments?currency=" + 'BTC' + "&kind=option").json()
r
# Out:
# {'jsonrpc': '2.0',
#  'result': [{'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188135,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 25500.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-25500-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188136,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 25500.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-25500-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188137,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 26000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-26000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188138,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 26000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-26000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188139,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 26500.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-26500-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188140,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 26500.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-26500-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188141,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 27000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-27000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188142,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 27000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-27000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188143,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 27250.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-27250-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188144,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 27250.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-27250-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188145,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 27500.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-27500-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188146,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 27500.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-27500-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188147,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 27750.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-27750-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188148,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 27750.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-27750-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188149,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 28000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-28000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188150,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 28000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-28000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188151,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 28250.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-28250-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188152,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 28250.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-28250-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188153,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 28500.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-28500-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188154,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 28500.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-28500-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188155,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 28750.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-28750-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188156,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 28750.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-28750-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188157,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 29000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-29000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188158,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 29000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-29000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697493840000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188438,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 29250.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-29250-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697493840000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188439,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 29250.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-29250-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188159,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 29500.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-29500-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188160,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 29500.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-29500-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697463000000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188408,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 29750.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-29750-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697463000000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188409,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 29750.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-29750-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188161,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 30000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-30000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697443260000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188162,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 30000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-30000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697463000000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188410,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 30250.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-30250-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697463000000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188411,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 30250.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-30250-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697462820000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188380,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 30500.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-30500-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697462820000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188381,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 30500.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-30500-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697463000000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188412,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 31000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-31000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697463000000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188413,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 31000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-31000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697463000000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188414,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 31500.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-31500-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697463000000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188415,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 31500.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-31500-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697463120000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188424,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 32000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-32000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697702400000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'day',
#    'creation_timestamp': 1697463120000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188425,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 32000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-19OCT23-32000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697788800000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'week',
#    'creation_timestamp': 1695888902000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 183153,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 15000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-20OCT23-15000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697788800000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'week',
#    'creation_timestamp': 1695888902000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 183154,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 15000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-20OCT23-15000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697788800000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'week',
#    'creation_timestamp': 1695888902000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 183155,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 20000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-20OCT23-20000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697788800000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'week',
#    'creation_timestamp': 1695888902000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 183156,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 20000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-20OCT23-20000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697788800000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'week',
#    'creation_timestamp': 1695888902000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 183157,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 24000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-20OCT23-24000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697788800000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'week',
#    'creation_timestamp': 1695888902000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 183158,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 24000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-20OCT23-24000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697788800000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'week',
#    'creation_timestamp': 1695888902000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 183159,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 25000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-20OCT23-25000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697788800000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'week',
#    'creation_timestamp': 1695888902000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 183160,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 25000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-20OCT23-25000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697788800000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'week',
#    'creation_timestamp': 1695888902000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 183161,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 26000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-20OCT23-26000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697788800000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'week',
#    'creation_timestamp': 1695888902000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 183162,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 26000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-20OCT23-26000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697788800000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'week',
#    'creation_timestamp': 1695888902000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 183163,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 27000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-20OCT23-27000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697788800000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'week',
#    'creation_timestamp': 1695888902000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 183164,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 27000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-20OCT23-27000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697788800000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'week',
#    'creation_timestamp': 1695888902000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 183165,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 28000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-20OCT23-28000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697788800000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'week',
#    'creation_timestamp': 1695888902000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 183166,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 28000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-20OCT23-28000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697788800000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'week',
#    'creation_timestamp': 1695888902000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 183167,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 29000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-20OCT23-29000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697788800000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'week',
#    'creation_timestamp': 1695888902000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 183168,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 29000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-20OCT23-29000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697788800000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'week',
#    'creation_timestamp': 1695888902000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 183169,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 30000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-20OCT23-30000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1697788800000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'week',
#    'creation_timestamp': 1695888902000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 183170,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 30000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-20OCT23-30000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
# ...
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1727424000000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'month',
#    'creation_timestamp': 1695801660000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 182564,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 32000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-27SEP24-32000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1727424000000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'month',
#    'creation_timestamp': 1695801660000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 182565,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 32000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-27SEP24-32000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1727424000000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'month',
#    'creation_timestamp': 1695912120000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 183425,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 34000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-27SEP24-34000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1727424000000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'month',
#    'creation_timestamp': 1695912120000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 183426,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 34000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-27SEP24-34000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1727424000000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'month',
#    'creation_timestamp': 1695801660000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 182566,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 35000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-27SEP24-35000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1727424000000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'month',
#    'creation_timestamp': 1695801660000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 182567,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 35000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-27SEP24-35000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1727424000000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'month',
#    'creation_timestamp': 1696233420000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 184476,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 36000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-27SEP24-36000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1727424000000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'month',
#    'creation_timestamp': 1696233420000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 184477,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 36000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-27SEP24-36000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1727424000000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'month',
#    'creation_timestamp': 1695801660000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 182568,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 40000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-27SEP24-40000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1727424000000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'month',
#    'creation_timestamp': 1695801660000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 182569,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 40000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-27SEP24-40000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1727424000000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'month',
#    'creation_timestamp': 1696232760000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 184472,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 45000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-27SEP24-45000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1727424000000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'month',
#    'creation_timestamp': 1696232760000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 184473,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 45000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-27SEP24-45000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1727424000000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'month',
#    'creation_timestamp': 1695801660000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 182570,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 50000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-27SEP24-50000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1727424000000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'month',
#    'creation_timestamp': 1695801660000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 182571,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 50000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-27SEP24-50000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1727424000000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'month',
#    'creation_timestamp': 1695801660000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 182572,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 60000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-27SEP24-60000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1727424000000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'month',
#    'creation_timestamp': 1695801660000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 182573,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 60000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-27SEP24-60000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1727424000000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'month',
#    'creation_timestamp': 1695801660000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 182574,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 70000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-27SEP24-70000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1727424000000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'month',
#    'creation_timestamp': 1695801660000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 182575,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 70000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-27SEP24-70000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1727424000000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'call',
#    'settlement_period': 'month',
#    'creation_timestamp': 1697463000000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188386,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 80000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-27SEP24-80000-C',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'},
#   {'tick_size_steps': [{'above_price': 0.005, 'tick_size': 0.0005}],
#    'quote_currency': 'BTC',
#    'min_trade_amount': 0.1,
#    'expiration_timestamp': 1727424000000,
#    'counter_currency': 'USD',
#    'settlement_currency': 'BTC',
#    'block_trade_tick_size': 0.0001,
#    'block_trade_min_trade_amount': 0.1,
#    'block_trade_commission': 0.00015,
#    'option_type': 'put',
#    'settlement_period': 'month',
#    'creation_timestamp': 1697463000000,
#    'contract_size': 1.0,
#    'base_currency': 'BTC',
#    'instrument_id': 188387,
#    'instrument_type': 'reversed',
#    'taker_commission': 0.0003,
#    'maker_commission': 0.0003,
#    'tick_size': 0.0001,
#    'strike': 80000.0,
#    'is_active': True,
#    'instrument_name': 'BTC-27SEP24-80000-P',
#    'kind': 'option',
#    'rfq': False,
#    'price_index': 'btc_usd'}],
#  'usIn': 1697676437490636,
#  'usOut': 1697676437490746,
#  'usDiff': 110,
#  'testnet': True}

# %%
import requests
import pandas as pd
from datetime import datetime as dt
from datetime import date, timedelta

def datetime_to_timestamp(datetime_obj): 
    """Converts a datetime object to a Unix timestamp in milliseconds."""
    return int(dt.timestamp(datetime_obj)*1000)

def timestamp_to_datetime(timestamp): 
    """Converts a Unix timestamp in milliseconds to a datetime object."""
    return dt.fromtimestamp(timestamp/1000)

def derivative_data(currency: str, kind: str, start_date: date, end_date: date, count: int = 10000) -> pd.DataFrame:
    """Returns derivative trade data for a specified currency and time range.

    Args:
        currency (str): The currency symbol, e.g. 'BTC'.
        kind (str): The type of derivative, either 'option' or 'future'.
        start_date (date): The start date of the time range (inclusive).
        end_date (date): The end date of the time range (inclusive).
        count (int, optional): The maximum number of trades to retrieve per request. Defaults to 10000.

    Returns:
        pandas.DataFrame: A dataframe of derivative trade data for the specified currency and time range.
    """

    # Validate input arguments
    assert isinstance(currency, str), "currency must be a string"
    assert isinstance(start_date, date), "start_date must be a date object"
    assert isinstance(end_date, date), "end_date must be a date object"
    assert start_date <= end_date, "start_date must be before or equal to end_date"

    derivative_list = []
    params = {
        "currency": currency, 
        "kind": kind,
        "count": count,
        "include_old": True,
        "start_timestamp": datetime_to_timestamp(dt.combine(start_date, dt.min.time())),
        "end_timestamp": datetime_to_timestamp(dt.combine(end_date, dt.max.time()))
    }

    url = 'https://history.deribit.com/api/v2/public/get_last_trades_by_currency_and_time'
    with requests.Session() as session:
        while True:
            response = session.get(url, params=params)
            response_data = response.json()
            if len(response_data["result"]["trades"]) == 0:
                break
            derivative_list.extend(response_data["result"]["trades"])
            params["start_timestamp"] = response_data["result"]["trades"][-1]["timestamp"] + 1
            if params["start_timestamp"] >= datetime_to_timestamp(dt.combine(end_date, dt.max.time())):
                break
                
    derivative_data = pd.DataFrame(derivative_list)
    if len(derivative_data) == 0:
        return derivative_data
    derivative_data["date_time"] = pd.to_datetime(derivative_data["timestamp"], unit='ms')
    df_duplicated = derivative_data.duplicated(subset=['trade_id'], keep='first')
    derivative_data = derivative_data[~df_duplicated]
    # derivative_data = derivative_data.drop(['block_trade_id'], axis=1)
    # derivative_data = derivative_data.assign(strike = derivative_data['instrument_name'].str.extract(r'-(\d+.\d+)-'))
    # derivative_data = derivative_data.assign(expire_date = derivative_data['instrument_name'].apply(lambda x : x.split('-')[1]))
    # derivative_data = derivative_data.assign(option_type = derivative_data['instrument_name'].apply(lambda x : x.split('-')[3]))
    # derivative_data['expire_date'] = pd.to_datetime(derivative_data['expire_date'], format='%d%b%y')

    # derivative_data['expiry_date'] =derivative_data['expire_date'] - derivative_data['timestamp']
    # derivative_data = derivative_data.sort_values(by=['date_time', 'strike', 'expiry_date', 'option_type'], ascending=[True, True, True, True])


    return derivative_data

data = derivative_data('BTC', 'option', date(2023, 1, 1), date(2023, 2, 2), 100)
data.to_csv('output.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\desktop\Documents\GitHub\crypto_strangle_straddle\main.ipynb Cell 4 line 7
#      <a href='vscode-notebook-cell:/c%3A/Users/desktop/Documents/GitHub/crypto_strangle_straddle/main.ipynb#W3sZmlsZQ%3D%3D?line=68'>69</a>     derivative_data = derivative_data.sort_values(by=['date_time', 'strike', 'expiry_date', 'option_type'], ascending=[True, True, True, True])
#      <a href='vscode-notebook-cell:/c%3A/Users/desktop/Documents/GitHub/crypto_strangle_straddle/main.ipynb#W3sZmlsZQ%3D%3D?line=71'>72</a>     return derivative_data
# ---> <a href='vscode-notebook-cell:/c%3A/Users/desktop/Documents/GitHub/crypto_strangle_straddle/main.ipynb#W3sZmlsZQ%3D%3D?line=73'>74</a> data = derivative_data('BTC', 'option', date(2023, 1, 1), date(2023, 2, 2), 100)
#      <a href='vscode-notebook-cell:/c%3A/Users/desktop/Documents/GitHub/crypto_strangle_straddle/main.ipynb#W3sZmlsZQ%3D%3D?line=74'>75</a> data.to_csv('output.csv')
#
# c:\Users\desktop\Documents\GitHub\crypto_strangle_straddle\main.ipynb Cell 4 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/desktop/Documents/GitHub/crypto_strangle_straddle/main.ipynb#W3sZmlsZQ%3D%3D?line=59'>60</a> df_duplicated = derivative_data.duplicated(subset=['trade_id'], keep='first')
#      <a href='vscode-notebook-cell:/c%3A/Users/desktop/Documents/GitHub/crypto_strangle_straddle/main.ipynb#W3sZmlsZQ%3D%3D?line=60'>61</a> derivative_data = derivative_data[~df_duplicated]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/desktop/Documents/GitHub/crypto_strangle_straddle/main.ipynb#W3sZmlsZQ%3D%3D?line=61'>62</a> derivative_data = derivative_data.drop(['block_trade_id'], axis=1)
#      <a href='vscode-notebook-cell:/c%3A/Users/desktop/Documents/GitHub/crypto_strangle_straddle/main.ipynb#W3sZmlsZQ%3D%3D?line=62'>63</a> derivative_data = derivative_data.assign(strike = derivative_data['instrument_name'].str.extract(r'-(\d+.\d+)-'))
#      <a href='vscode-notebook-cell:/c%3A/Users/desktop/Documents/GitHub/crypto_strangle_straddle/main.ipynb#W3sZmlsZQ%3D%3D?line=63'>64</a> derivative_data = derivative_data.assign(expire_date = derivative_data['instrument_name'].apply(lambda x : x.split('-')[1]))
#
# File c:\Users\desktop\Documents\GitHub\crypto_strangle_straddle\.venv\lib\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
#    5354         errors=errors,
#    5355     )
#
# File c:\Users\desktop\Documents\GitHub\crypto_strangle_straddle\.venv\lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File c:\Users\desktop\Documents\GitHub\crypto_strangle_straddle\.venv\lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File c:\Users\desktop\Documents\GitHub\crypto_strangle_straddle\.venv\lib\site-packages\pandas\core\indexes\base.py:6992, in Index.drop(self, labels, errors)
#    6990 if mask.any():
#    6991     if errors != "ignore":
# -> 6992         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    6993     indexer = indexer[~mask]
#    6994 return self.delete(indexer)
#
# KeyError: "['block_trade_id'] not found in axis"

# %%
data['instrument_name'].str

# %%
df_duplicated = data.duplicated(subset=['trade_id'], keep='first')
df_unique = data[~df_duplicated]
df_unique = df_unique.drop(['block_trade_id'], axis=1)
df_unique['timestamp'] = pd.to_datetime((df_unique['timestamp']), unit='ms')
df_unique = df_unique.assign(strike = df_unique['instrument_name'].str.extract(r'-(\d+.\d+)-'))
df_unique = df_unique.assign(expire_date = df_unique['instrument_name'].apply(lambda x : x.split('-')[1]))
df_unique = df_unique.assign(option_type = df_unique['instrument_name'].apply(lambda x : x.split('-')[3]))

df_unique['expire_date'] = pd.to_datetime(df_unique['expire_date'], format='%d%b%y')

# Calculate 'expiry_date' by subtracting 'expire_date' from 'timestamp'
df_unique['expiry_date'] =df_unique['expire_date'] - df_unique['timestamp']
df_unique = df_unique.sort_values(by=['date_time', 'strike', 'expiry_date', 'option_type'], ascending=[True, True, True, True])
# # Convert 'expiry_date' column to date format
# df_unique['expiry_date'] = df_unique['expiry_date'].apply(lambda x: x.date())

df_unique.to_csv('output.csv')

# %%
dt.strptime(str(df_unique['expire_date'][0]), '%Y-%m-%d %H:%M:%S')
# Out:
# datetime.datetime(2022, 2, 18, 0, 0)

# %%
# r = requests.get('https://test.deribit.com/api/v2/public/get_instruments?currency=BTC&kind=option').json()
r = requests.get('https://test.deribit.com/api/v2/public/get_order_book_by_instrument_id?instrument_id=187151&depth=1').json()
# r = requests.get('https://test.deribit.com/api/v2/public/get_index_price?index_name=btc_usd').json()
r
# Out:
# {'jsonrpc': '2.0',
#  'error': {'message': 'not_found',
#   'data': {'key': 187151, 'object': 'instrument_id'},
#   'code': 13020},
#  'testnet': True,
#  'usIn': 1697676738812682,
#  'usOut': 1697676738812750,
#  'usDiff': 68}
